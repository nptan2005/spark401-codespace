# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName('sparkdf') \
    .master("local[2]") \
    .config("spark.driver.memory","2g") \
    .config("spark.sql.shuffle.partitions","8") \
    .getOrCreate() # Init SparkSession

d = [["1", "sravan", "company 1"],
        ["2", "ojaswi", "company 1"], 
        ["3", "rohith", "company 2"],
        ["4", "sridevi", "company 1"], 
        ["5", "bobby", "company 1"]]

cols = ['ID', 'Name', 'Company']
df = spark.createDataFrame(d, cols)
df.show()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/16 10:07:47 WARN Utils: Your hostname, codespaces-3d0492, resolves to a loopback address: 127.0.0.1; using 10.0.3.187 instead (on interface eth0)
# 25/12/16 10:07:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/16 10:07:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/12/16 10:07:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# [Stage 0:>                                                          (0 + 1) / 1]
# +---+-------+---------+
# | ID|   Name|  Company|
# +---+-------+---------+
# |  1| sravan|company 1|
# |  2| ojaswi|company 1|
# |  3| rohith|company 2|
# |  4|sridevi|company 1|
# |  5|  bobby|company 1|
# +---+-------+---------+

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName('sparkdf') \
    .master("local[2]") \
    .config("spark.driver.memory","2g") \
    .config("spark.sql.shuffle.partitions","8") \
    .getOrCreate() # Init SparkSession

d1 = [["1", "45000", "IT"],
         ["2", "145000", "Manager"],
         ["6", "45000", "HR"],
         ["5", "34000", "Sales"]]

cols = ['ID', 'salary', 'department']
df1 = spark.createDataFrame(d1, cols)

df1.show()
# Out:
# +---+------+----------+
# | ID|salary|department|
# +---+------+----------+
# |  1| 45000|        IT|
# |  2|145000|   Manager|
# |  6| 45000|        HR|
# |  5| 34000|     Sales|
# +---+------+----------+

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName('sparkdf') \
    .master("local[2]") \
    .config("spark.driver.memory","2g") \
    .config("spark.sql.shuffle.partitions","8") \
    .getOrCreate() # Init SparkSession

# first DataFrame
d1 = [("1", "sravan", "company 1"),
      ("2", "ojaswi", "company 1"),
      ("3", "rohith", "company 2"),
      ("4", "sridevi", "company 1"),
      ("5", "bobby", "company 1")]
cols1 = ['id', 'name', 'company']
df1 = spark.createDataFrame(d1, cols1)

# second DataFrame
d2 = [("1", "45000", "IT"),
      ("2", "145000", "Manager"),
      ("6", "45000", "HR"),
      ("5", "34000", "Sales")]
cols2 = ['id', 'salary', 'department']
df2 = spark.createDataFrame(d2, cols2)

df1.join(df2, df1.id == df2.id, "inner").show()
# Out:
# +---+------+---------+---+------+----------+
# | id|  name|  company| id|salary|department|
# +---+------+---------+---+------+----------+
# |  1|sravan|company 1|  1| 45000|        IT|
# |  2|ojaswi|company 1|  2|145000|   Manager|
# |  5| bobby|company 1|  5| 34000|     Sales|
# +---+------+---------+---+------+----------+

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName('sparkdf') \
    .master("local[2]") \
    .config("spark.driver.memory","2g") \
    .config("spark.sql.shuffle.partitions","8") \
    .getOrCreate() # Init SparkSession

# first dataframe data
d1 = [["1", "sravan", "company 1"],
      ["2", "ojaswi", "company 1"],
      ["3", "rohith", "company 2"],
      ["4", "sridevi", "company 1"],
      ["5", "bobby", "company 1"]]
cols1 = ['ID', 'NAME', 'Company']
df1 = spark.createDataFrame(d1, cols1)

# second dataframe data
d2 = [["1", "45000", "IT"],
      ["2", "145000", "Manager"],
      ["6", "45000", "HR"],
      ["5", "34000", "Sales"]]
cols2 = ['ID', 'salary', 'department']
df2 = spark.createDataFrame(d2, cols2)

df1.join(df2, df1.ID == df2.ID, "outer").show()
# Out:
# +----+-------+---------+----+------+----------+
# |  ID|   NAME|  Company|  ID|salary|department|
# +----+-------+---------+----+------+----------+
# |   1| sravan|company 1|   1| 45000|        IT|
# |   2| ojaswi|company 1|   2|145000|   Manager|
# |   3| rohith|company 2|NULL|  NULL|      NULL|
# |   4|sridevi|company 1|NULL|  NULL|      NULL|
# |   5|  bobby|company 1|   5| 34000|     Sales|
# |NULL|   NULL|     NULL|   6| 45000|        HR|
# +----+-------+---------+----+------+----------+

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName('sparkdf') \
    .master("local[2]") \
    .config("spark.driver.memory","2g") \
    .config("spark.sql.shuffle.partitions","8") \
    .getOrCreate() # Init SparkSession

# first dataframe data
d1 = [["1", "sravan", "company 1"],
      ["2", "ojaswi", "company 1"],
      ["3", "rohith", "company 2"],
      ["4", "sridevi", "company 1"],
      ["5", "bobby", "company 1"]]
cols1 = ['ID', 'NAME', 'Company']
df1 = spark.createDataFrame(d1, cols1)

# second dataframe data
d2 = [["1", "45000", "IT"],
      ["2", "145000", "Manager"],
      ["6", "45000", "HR"],
      ["5", "34000", "Sales"]]
cols2 = ['ID', 'salary', 'department']
df2 = spark.createDataFrame(d2, cols2)

df1.join(df2, df1.ID == df2.ID, "full").show()
# Out:
# +----+-------+---------+----+------+----------+
# |  ID|   NAME|  Company|  ID|salary|department|
# +----+-------+---------+----+------+----------+
# |   1| sravan|company 1|   1| 45000|        IT|
# |   2| ojaswi|company 1|   2|145000|   Manager|
# |   3| rohith|company 2|NULL|  NULL|      NULL|
# |   4|sridevi|company 1|NULL|  NULL|      NULL|
# |   5|  bobby|company 1|   5| 34000|     Sales|
# |NULL|   NULL|     NULL|   6| 45000|        HR|
# +----+-------+---------+----+------+----------+

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName('sparkdf') \
    .master("local[2]") \
    .config("spark.driver.memory","2g") \
    .config("spark.sql.shuffle.partitions","8") \
    .getOrCreate() # Init SparkSession

# First dataframe data
d1 = [["1", "sravan", "company 1"],
      ["2", "ojaswi", "company 1"],
      ["3", "rohith", "company 2"],
      ["4", "sridevi", "company 1"],
      ["5", "bobby", "company 1"]]
cols1 = ['ID', 'NAME', 'Company']
df1 = spark.createDataFrame(d1, cols1)

# Second dataframe data
d2 = [["1", "45000", "IT"],
      ["2", "145000", "Manager"],
      ["6", "45000", "HR"],
      ["5", "34000", "Sales"]]
cols2 = ['ID', 'salary', 'department']
df2 = spark.createDataFrame(d2, cols2)

df1.join(df2, df1.ID == df2.ID, "fullouter").show()
# Out:
# +----+-------+---------+----+------+----------+
# |  ID|   NAME|  Company|  ID|salary|department|
# +----+-------+---------+----+------+----------+
# |   1| sravan|company 1|   1| 45000|        IT|
# |   2| ojaswi|company 1|   2|145000|   Manager|
# |   3| rohith|company 2|NULL|  NULL|      NULL|
# |   4|sridevi|company 1|NULL|  NULL|      NULL|
# |   5|  bobby|company 1|   5| 34000|     Sales|
# |NULL|   NULL|     NULL|   6| 45000|        HR|
# +----+-------+---------+----+------+----------+
