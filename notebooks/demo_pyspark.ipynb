# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Spark401-Demo") \
    .master("local[*]") \
    .getOrCreate()

data = [
    (1, "Alice", 30),
    (2, "Bob", 25)
]

df = spark.createDataFrame(data, ["id", "name", "age"])
df.show()
